# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 
from PIL import Image
import requests
from io import BytesIO
plt.figure(figsize=(10, 10))
response_cat1 = requests.get('https://i.yapx.cc/MvQ5k.gif')
img_cat1 = Image.open(BytesIO(response_cat1.content))
plt.imshow(img_cat1)
